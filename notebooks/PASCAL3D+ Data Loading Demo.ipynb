# %%
import sys
sys.path.insert(0, '../')
import os
from datasets import pascal3d

# %% [markdown]
# #### Download the preprocessed Pascal3D+ dataset from here:
#
# https://drive.google.com/open?id=1bDcISYXmCcTqZhhCX-bhTuUCmEH1Q8YF
#
# and place it to $PROJECT_DIR/data/

# %% [markdown]
# #### Show available classes

# %%
pascal3d.PASCAL_CLASSES
# Out:
# ['aeroplane',
#  'bicycle',
#  'boat',
#  'bottle',
#  'bus',
#  'car',
#  'chair',
#  'diningtable',
#  'motorbike',
#  'sofa',
#  'train',
#  'tvmonitor']

# %% [markdown]
# #### Load dataset

# %%
pascaldb_path = '../data/pascal3d+_imagenet_train_test.h5'
cls = 'car' # if cls is None, all classes will be loaded

x_train, y_train, x_val, y_val, x_test, y_test = pascal3d.load_pascal_data(pascaldb_path, cls=cls)

# %% [markdown]
# #### Example of converting biternion (cos, sin) representation to degrees

# %%
import utils.angles as ang

y_train_azimuth_deg = ang.bit2deg(y_train[:, 0:2])
y_train_elevation_deg = ang.bit2deg(y_train[:, 2:4])
y_train_tilt_deg = ang.bit2deg(y_train[:, 4:6])

# %% [markdown]
# #### Show test image

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

frame_id = 4392 #np.random.randint(x_train.shape[0])

plt.imshow(x_train[frame_id])
print('class %s, azimuth angle: %f' %(cls, y_train_azimuth_deg[frame_id]))
# Out:
# class car, azimuth angle: 27.073571
